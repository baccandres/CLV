# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import sys
sys.path.append('..')
import src.tools as tools

# %%
#RFM Libraries
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from statsmodels.graphics.gofplots import qqplot
from scipy import stats
from scipy.stats import kruskal

#CLTV Libraries:
from datetime import datetime, timedelta,date
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from __future__ import division
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
a = pd.read_csv('../data/Year 2009-2010.csv', encoding='unicode_escape')
b = pd.read_csv('../data/Year 2010-2011.csv', encoding='unicode_escape')
retail = pd.concat([a,b], ignore_index=True)
retail.columns= retail.columns.str.lower()

# %%
retail = retail.query("country=='United Kingdom'").reset_index(drop=True)
retail.invoicedate = pd.to_datetime(retail.invoicedate)
retail['year'] = retail.invoicedate.dt.year
retail['month'] = retail.invoicedate.dt.month
retail['week'] = retail.invoicedate.dt.isocalendar().week
retail['day'] = retail.invoicedate.dt.day
retail['hour'] = retail.invoicedate.dt.hour
retail['revenue'] = retail.price * retail.quantity
retail = retail.query("year>2009").reset_index(drop=True)

# %% [markdown]
# ### Customer Lifetime Value for groups of 3 and 6 months
# ### RFM Part

# %%
m3 = retail[(retail.invoicedate < pd.Timestamp(2011,6,1)) & (retail.invoicedate >= pd.Timestamp(2011,3,1))].reset_index(drop=True)
m6 = retail[(retail.invoicedate >= pd.Timestamp(2011,6,1)) & (retail.invoicedate < pd.Timestamp(2011,12,1))].reset_index(drop=True)

# %% [markdown]
# #### Recency, Frequency, Monetary

# %%
df_3m = tools.rfm(m3)
df_6m = tools.rfm(m6)
df_2y = tools.rfm(retail)

# %% [markdown]
# #### Determine Optimal Number of Clusters per Dataframe

# %%
tools.rfmclusters(df_3m)

# %% [markdown]
# rfm clusters = 2, 3, 3

# %%
tools.rfmclusters(df_6m)

# %% [markdown]
# rfm clusters = 3, 3, 3

# %%
tools.rfmclusters(df_2y)

# %% [markdown]
# rfm clusters = 2, 3, 3

# %% [markdown]
# #### Cluster Analysis

# %%
df_3m = tools.clustering(df_3m, 3)
df_6m = tools.clustering(df_6m, 3)
df_2y = tools.clustering(df_2y, 3);

# %% [markdown]
# #### Scoring

# %%
df_3m = tools.score(df_3m)
df_6m = tools.score(df_6m)
df_2y = tools.score(df_2y);

# %%
fig, ax = plt.subplots(1,3)
sns.countplot(y='score', data=df_3m, ax=ax[0])
sns.countplot(y='score', data=df_6m, ax=ax[1])
sns.countplot(y='score', data=df_2y, ax=ax[2]);

# %% [markdown]
# #### Segmentation Based on Score

# %%
df_3m = tools.segmentation(df_3m)
df_6m = tools.segmentation(df_6m)
df_2y = tools.segmentation(df_2y);

# %%
fig, ax = plt.subplots(1,3)
sns.countplot(x='segment', data=df_3m, ax=ax[0])
sns.countplot(x='segment', data=df_6m, ax=ax[1])
sns.countplot(x='segment', data=df_2y, ax=ax[2]);

# %%
df_3m.head()
# Out:
#    customer id  recency  frequency  monetary  r_cluster  f_cluster  m_cluster  \
# 0      14620.0       12         30    393.28          1          0          0
# 1      14740.0        4         89   1448.21          1          2          0
# 2      13880.0       25         38    718.63          1          0          0
# 3      16462.0       91          1     34.00          2          0          0
# 4      17068.0       11         76   1480.95          1          2          0
#
#    score    segment
# 0      1  Mid-Value
# 1      3  Mid-Value
# 2      1  Mid-Value
# 3      2  Mid-Value
# 4      3  Mid-Value

# %%
df_6m.head()
# Out:
#    customer id  recency  frequency  monetary  r_cluster  f_cluster  m_cluster  \
# 0      15643.0      170         13    310.30          1          0          0
# 1      14842.0       26        155   2441.80          0          0          0
# 2      15124.0       13         15    184.19          0          0          0
# 3      16422.0        8        194  16756.31          0          2          2
# 4      15240.0       35         56   1077.47          0          0          0
#
#    score     segment
# 0      1   Mid-Value
# 1      0   Low-Value
# 2      0   Low-Value
# 3      4  High-Value
# 4      0   Low-Value

# %% [markdown]
# ### CLV Part

# %% [markdown]
# There is no cost specified in the dataset. That’s why Monetary becomes our CLTV directly.

# %%
#print(df_3m.shape[0], df_6m.shape[0])

# %%
#df_merge = pd.merge(df_3m, df_6m, how='left').fillna(0)

# %%
corr = df_3m.corr(method='pearson')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/xv/v29gqxhs4b5gth_lvdz9tgl80000gn/T/ipykernel_8193/3703104003.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_1b694_row0_col0, #T_1b694_row1_col1, #T_1b694_row2_col2, #T_1b694_row3_col3, #T_1b694_row4_col4, #T_1b694_row5_col5, #T_1b694_row6_col6, #T_1b694_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col2, #T_1b694_row4_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col5, #T_1b694_row4_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1b694_row0_col7, #T_1b694_row1_col2, #T_1b694_row1_col3, #T_1b694_row1_col5, #T_1b694_row1_col6, #T_1b694_row2_col0, #T_1b694_row2_col1, #T_1b694_row2_col4, #T_1b694_row3_col1, #T_1b694_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1b694_row1_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_1b694_row1_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1b694_row1_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1b694_row2_col3, #T_1b694_row3_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_1b694_row2_col5, #T_1b694_row7_col4 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_1b694_row2_col6, #T_1b694_row4_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1b694_row2_col7, #T_1b694_row7_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_1b694_row3_col0, #T_1b694_row3_col4, #T_1b694_row5_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_1b694_row3_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1b694_row3_col6, #T_1b694_row4_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_1b694_row3_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1b694_row4_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1b694_row4_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1b694_row4_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1b694_row5_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1b694_row5_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_1b694_row5_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1b694_row5_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_1b694_row5_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_1b694_row6_col0, #T_1b694_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1b694_row6_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_1b694_row6_col2, #T_1b694_row6_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1b694_row6_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_1b694_row6_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1b694_row6_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1b694_row7_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1b694_row7_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_1b694_row7_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_1b694_row7_col6 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# </style>
# <table id="T_1b694_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >customer id</th>
#       <th class="col_heading level0 col1" >recency</th>
#       <th class="col_heading level0 col2" >frequency</th>
#       <th class="col_heading level0 col3" >monetary</th>
#       <th class="col_heading level0 col4" >r_cluster</th>
#       <th class="col_heading level0 col5" >f_cluster</th>
#       <th class="col_heading level0 col6" >m_cluster</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b694_level0_row0" class="row_heading level0 row0" >customer id</th>
#       <td id="T_1b694_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_1b694_row0_col1" class="data row0 col1" >-0.00</td>
#       <td id="T_1b694_row0_col2" class="data row0 col2" >-0.03</td>
#       <td id="T_1b694_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_1b694_row0_col4" class="data row0 col4" >-0.02</td>
#       <td id="T_1b694_row0_col5" class="data row0 col5" >-0.01</td>
#       <td id="T_1b694_row0_col6" class="data row0 col6" >-0.03</td>
#       <td id="T_1b694_row0_col7" class="data row0 col7" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T